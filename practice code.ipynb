# %%
# %pip install anthropic python-dotenv
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 662.1/662.1 kB 15.1 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 25.3 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10/10 [anthropic]  9/10 [anthropic]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from anthropic import Anthropic

client = Anthropic()

response = client.messages.create(
    model="claude-opus-4-6",
    max_tokens=1024,
    messages=[
        {"role": "user", "content": "Write a short poem about hip-hop in 5 lines"}
    ]
)

print(response.content[0].text)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 5
#       1 from anthropic import Anthropic
#       2
#       3 client = Anthropic()
#       4
# ----> 5 response = client.messages.create(
#       6     model="claude-opus-4-6",
#       7     max_tokens=1024,
#       8     messages=[
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/anthropic/_utils/_utils.py:268, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     266             msg = f"Missing required argument: {quote(missing[0])}"
#     267     raise TypeError(msg)
# --> 268 return func(*args, **kwargs)
#
# ...

# %%
from anthropic import Anthropic

client = Anthropic(api_key="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")  # Paste your actual key here

response = client.messages.create(
    model="claude-opus-4-6",
    max_tokens=1024,
    messages=[
        {"role": "user", "content": "Write a short poem about hip-hop in 5 lines"}
    ]
)

print(response.content[0].text)
# Out:
# # The Beat Goes On
#
# Beats pulse through the city night,
# Rhymes cut sharp like neon light,
# Stories told from street to stage,
# Every verse turns pain to page,
# Hip-hop's voice burns ever bright.
